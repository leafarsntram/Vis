# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

censos = ['1970','1980','1991','2000','2010']
norted = np.array([28675110,35419156,42470225,47693253,53081950])
norte = np.array( [ 4188313, 6767249,10257266,12893561,15864454])
centro = np.array([ 4629640, 7003515, 9412242,11616745,14058094])
sudeste= np.array([40331969,52580527,62660700,72297351,80364410])
sul = np.array(   [16683551,19380126,22117026,25089783,27386891])

ind = [country for country in censos]
 
plt.bar(ind, norted, width=0.6, label='Nordeste', color='gold', bottom=norte+centro+sul+sudeste)
plt.bar(ind, norte, width=0.6, label='Norte', color='green', bottom=centro+sul+sudeste)
plt.bar(ind, centro, width=0.6, label='Centro', color='#CD7F32',  bottom=sul+sudeste)
plt.bar(ind, sudeste, width=0.6, label='Sudeste', color='silver',  bottom=sul)
plt.bar(ind, sul, width=0.6, label='Sul', color='blue')

total = [94508583,121150573,146917459,169590693,190755799]


plt.rcParams["figure.figsize"] = (15,10)
plt.box(False)
plt.xticks(ind, censos)
plt.ylabel("População")
plt.yticks([50000000,100000000,150000000,200000000],['50M','100M','150M','200M'])
plt.xlabel("Censos")
plt.legend(loc="upper left")
plt.title("Distribuição da população residente por Região")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
