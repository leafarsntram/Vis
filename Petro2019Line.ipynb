# %%
import plotly.graph_objects as go
import plotly.express as px
import pandas as pd
df = pd.read_html('http://github.com/leafarsntram/Vis/blob/master/data/PETR4c.csv')[0]

fig = px.line(df, x='Date', y='close', title='Ações 2019')
#fig = px.line(df1, x='Date', y='Close')

fig.update_xaxes(rangeslider_visible=True)
fig.show()
# Out:
# <div>
#
#
#             <div id="0d647204-2afe-482e-9f16-5b3c78c63764" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("0d647204-2afe-482e-9f16-5b3c78c63764")) {
#                     Plotly.newPlot(
#                         '0d647204-2afe-482e-9f16-5b3c78c63764',
# ...
