# %%
import pandas as pd
import matplotlib.pyplot as plt
    
# replicate Data from question in DataFrame
#v = [[12,34,51], [9,76,12], [12,23,7], [54,4,34]]
#df = pd.DataFrame(v, columns=["01/01/2016","01/07/2016","01/14/2017"], 
#                      index=["ABC", "XYZ", "PQR", "DEF"])

df= pd.read_csv(r'C:/Users/Sophia/Downloads/temp/PETR4.csv', delimiter = ',',header=None #, names = ['Date','Close' ]
                 , parse_dates=False, dayfirst=True)
x,y = df[1],df[2]/1000000
#modo 1
# plot
#plt.title("PETR4 - Volume x Preço - 2019", fontdict={'color': "Darkblue", 'fontsize':60})
#plt.plot(x, y,  linestyle='none', marker='o')
#plt.box(False)
#plt.show()
#plt.rcParams["figure.figsize"] =(60,60)

#Modo 2
fig, ax = plt.subplots(figsize=(15,15))
ax.scatter(y,x)
ax.set_xlabel(r'Volume  (em milhões)', fontsize=25, color = "darkblue")
ax.set_ylabel(r'Preço (R$)', fontsize=25, color = "darkblue")
ax.set_title('PETR4 - Preço x Volume \n 2019', fontsize=50, color = "darkblue")
#ax.set_xticks([0, 1])
fig.tight_layout()
plt.show()
